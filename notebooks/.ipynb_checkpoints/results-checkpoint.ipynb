# %% [markdown]
# ### Mean test pass rate

# %%
import pandas as pd

df = pd.read_csv("../results/raw_csv/tests_with_cases.csv")

table = (
    df.groupby(["model","generation"])["pass_rate"]
      .mean()
      .reset_index()
)

table.to_csv("../results/tables/mean_pass_rate_model_gen.csv", index=False)
table
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 11
#       3 df = pd.read_csv("../results/raw_csv/tests_with_cases.csv")
#       5 table = (
#       6     df.groupby(["model","generation"])["pass_rate"]
#       7       .mean()
#       8       .reset_index()
#       9 )
# ---> 11 table.to_csv("results/tables/mean_pass_rate_model_gen.csv", index=False)
#      12 table
#
# File ~/Documents/llmcova/env/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
